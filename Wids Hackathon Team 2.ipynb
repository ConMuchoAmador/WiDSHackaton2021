# %%
#import needed modules
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib as cm #to avoid a module overlap
import seaborn as sns
import matplotlib.pyplot as plt #to avoid a module overlap
from sklearn.decomposition import PCA

# %matplotlib inline

# %%
#Read in the excel file
df = pd.read_csv('C:/Users/eamador/OneDrive - Western Governors University/Desktop/School/\
UnlabeledWiDS2021.csv')
pd.options.display.max_rows = 500
df.shape
# Out:
# (10234, 180)

# %%
#Find number of rows and columns, list what the columns are and their data types
df.dtypes
# Out:
# Unnamed: 0                       int64
# encounter_id                     int64
# hospital_id                      int64
# age                              int64
# bmi                            float64
# elective_surgery                 int64
# ethnicity                       object
# gender                          object
# height                         float64
# hospital_admit_source           object
# icu_admit_source                object
# icu_id                           int64
# icu_stay_type                   object
# icu_type                        object
# pre_icu_los_days               float64
# readmission_status               int64
# weight                         float64
# albumin_apache                 float64
# apache_2_diagnosis             float64
# apache_3j_diagnosis            float64
# apache_post_operative            int64
# arf_apache                       int64
# bilirubin_apache               float64
# bun_apache                     float64
# ...

# %%
#Check for duplicate rows
dups = df.duplicated(subset=None, keep=False)
counter =0
for i in dups:
    if i == True:
        counter= counter+1
print("Number of Duplciates: ", counter)
# Out:
# Number of Duplciates:  0

# %%
#Find nulls by columns
# from: https://thispointer.com/python-pandas-count-number-of-nan-or-missing-values-in-dataframe-also-row-column-wise/
print("***Count all NaN in a DataFrame (both columns & Rows)***")
print("Total NaN in Dataframe" , df.isnull().sum().sum(), sep='\n')
print("***Count NaN in each column of a DataFrame***")
print("Nan in each column" , df.isnull().sum(), sep='\n')
# Out:
# ***Count all NaN in a DataFrame (both columns & Rows)***
# Total NaN in Dataframe
# 631409
# ***Count NaN in each column of a DataFrame***
# Nan in each column
# Unnamed: 0                        0
# encounter_id                      0
# hospital_id                       0
# age                               0
# bmi                            1015
# elective_surgery                  0
# ethnicity                       204
# gender                            5
# height                          301
# hospital_admit_source          2733
# icu_admit_source                 25
# icu_id                            0
# icu_stay_type                     0
# icu_type                          0
# pre_icu_los_days                  0
# readmission_status                0
# weight                          908
# albumin_apache                 6055
# apache_2_diagnosis              170
# apache_3j_diagnosis             108
# apache_post_operative             0
# arf_apache                        0
# ...

# %%
df.select_dtypes(include=[np.number]).dtypes
#df_normalized = (df-df.mean())/df.std() #Normalize dataset in preparation for analysis
#pca = PCA(n_components=df_normalized.shape[1])
#pca.fit(df_normalized)
#df_pca = pd.DataFrame(pca.transform(df_normalized), columns = ['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18'])
# Out:
# Unnamed: 0                       int64
# encounter_id                     int64
# hospital_id                      int64
# age                              int64
# bmi                            float64
# elective_surgery                 int64
# height                         float64
# icu_id                           int64
# pre_icu_los_days               float64
# readmission_status               int64
# weight                         float64
# albumin_apache                 float64
# apache_2_diagnosis             float64
# apache_3j_diagnosis            float64
# apache_post_operative            int64
# arf_apache                       int64
# bilirubin_apache               float64
# bun_apache                     float64
# creatinine_apache              float64
# fio2_apache                    float64
# gcs_eyes_apache                float64
# gcs_motor_apache               float64
# gcs_unable_apache              float64
# gcs_verbal_apache              float64
# ...
